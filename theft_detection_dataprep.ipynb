# %% [markdown]
# import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                             CONS_NO  FLAG  2014/1/1  2014/1/10  2014/1/11  \
# 0  0387DD8A07E07FDA6271170F86AD9151     1       NaN        NaN        NaN
# 1  01D6177B5D4FFE0CABA9EF17DAFC2B84     1       NaN        NaN        NaN
# 2  4B75AC4F2D8434CFF62DB64D0BB43103     1       NaN        NaN        NaN
# 3  B32AC8CC6D5D805AC053557AB05F5343     1       NaN        NaN        NaN
# 4  EDFC78B07BA2908B3395C4EB2304665E     1       2.9       3.42       3.81
#
#    2014/1/12  2014/1/13  2014/1/14  2014/1/15  2014/1/16  ...  2016/9/28  \
# 0        NaN        NaN        NaN        NaN        NaN  ...      10.12
# 1        NaN        NaN        NaN        NaN        NaN  ...       0.00
# 2        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 3        NaN        NaN        NaN        NaN        NaN  ...       6.50
# 4       4.58       3.56       4.25       3.86       3.53  ...      17.77
#
#    2016/9/29  2016/9/3  2016/9/30  2016/9/4  2016/9/5  2016/9/6  2016/9/7  \
# ...

# %%
df.isnull().sum()
# Out:
# CONS_NO          0
# FLAG             0
# 2014/1/1     16502
# 2014/1/10    16460
# 2014/1/11    16461
#              ...
# 2016/9/5       499
# 2016/9/6       522
# 2016/9/7       405
# 2016/9/8       328
# 2016/9/9       345
# Length: 1036, dtype: int64

# %%
df.describe()
# Out:
#                FLAG      2014/1/1     2014/1/10     2014/1/11    2014/1/12  \
# count  42372.000000  25870.000000  25912.000000  25911.000000  25912.00000
# mean       0.085316      7.168735      6.954202      6.784099      7.08430
# std        0.279354     34.131237     40.017856     38.327058     31.98716
# min        0.000000      0.000000      0.000000      0.000000      0.00000
# 25%        0.000000      0.000000      0.000000      0.000000      0.00000
# 50%        0.000000      3.310000      2.870000      2.900000      3.35000
# 75%        0.000000      8.910000      8.170000      8.210000      8.76000
# max        1.000000   3318.000000   3966.000000   4392.000000   3414.00000
#
#           2014/1/13     2014/1/14     2014/1/15     2014/1/16     2014/1/17  \
# count  25912.000000  25912.000000  25915.000000  25924.000000  25925.000000
# mean      10.516470      7.219633      7.341512      7.160004      6.839875
# ...

# %%
pd.set_option('display.max_columns', None)
print(df.columns)
# Out:
# Index(['CONS_NO', 'FLAG', '2014/1/1', '2014/1/10', '2014/1/11', '2014/1/12',
#        '2014/1/13', '2014/1/14', '2014/1/15', '2014/1/16',
#        ...
#        '2016/9/28', '2016/9/29', '2016/9/3', '2016/9/30', '2016/9/4',
#        '2016/9/5', '2016/9/6', '2016/9/7', '2016/9/8', '2016/9/9'],
#       dtype='object', length=1036)

# %%
df.dtypes
# Out:
# CONS_NO       object
# FLAG           int64
# 2014/1/1     float64
# 2014/1/10    float64
# 2014/1/11    float64
#               ...
# 2016/9/5     float64
# 2016/9/6     float64
# 2016/9/7     float64
# 2016/9/8     float64
# 2016/9/9     float64
# Length: 1036, dtype: object

# %%
df.shape
# Out:
# (42372, 1036)

# %%
# Drop the 'CONS_NO' column
df.drop(columns=['CONS_NO'], inplace=True)

# Convert 'FLAG' column to integer type
df['FLAG'] = df['FLAG'].astype(int)

# %%
df.dtypes
# Out:
# FLAG           int32
# 2014/1/1     float64
# 2014/1/10    float64
# 2014/1/11    float64
# 2014/1/12    float64
#               ...
# 2016/9/5     float64
# 2016/9/6     float64
# 2016/9/7     float64
# 2016/9/8     float64
# 2016/9/9     float64
# Length: 1035, dtype: object

# %%
import pandas as pd
from scipy import stats

# Handling missing values
# Interpolate missing values along the columns
df.interpolate(method='linear', axis=1, inplace=True)

# %%
df.head()
# Out:
#    FLAG  2014/1/1  2014/1/10  2014/1/11  2014/1/12  2014/1/13  2014/1/14  \
# 0   1.0  1.789375   2.578750   3.368125   4.157500   4.946875   5.736250
# 1   1.0  0.998632   0.997264   0.995896   0.994528   0.993160   0.991792
# 2   1.0  1.013776   1.027551   1.041327   1.055103   1.068878   1.082654
# 3   1.0  1.033438   1.066875   1.100313   1.133750   1.167188   1.200625
# 4   1.0  2.900000   3.420000   3.810000   4.580000   3.560000   4.250000
#
#    2014/1/15  2014/1/16  2014/1/17  2014/1/18  2014/1/19   2014/1/2  \
# 0   6.525625   7.315000   8.104375   8.893750   9.683125  10.472500
# 1   0.990424   0.989056   0.987688   0.986320   0.984952   0.983584
# 2   1.096430   1.110205   1.123981   1.137756   1.151532   1.165308
# 3   1.234062   1.267500   1.300937   1.334375   1.367812   1.401250
# 4   3.860000   3.530000   3.410000   0.850000   0.880000   5.640000
#
#    2014/1/20  2014/1/21  2014/1/22  2014/1/23  2014/1/24  2014/1/25  \
# ...

# %%
df.isnull().sum()
# Out:
# FLAG         0
# 2014/1/1     0
# 2014/1/10    0
# 2014/1/11    0
# 2014/1/12    0
#             ..
# 2016/9/5     0
# 2016/9/6     0
# 2016/9/7     0
# 2016/9/8     0
# 2016/9/9     0
# Length: 1035, dtype: int64

# %%
import numpy as np
from scipy import stats

# Exclude the 'FLAG' column from outlier detection
data_without_flag = df.drop(columns=['FLAG'])

# Outlier detection and removal using Z-score
# Define a threshold for Z-score (e.g., 3)
z_threshold = 3
z_scores = stats.zscore(data_without_flag)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < z_threshold).all(axis=1)
df = df[filtered_entries]

# Check the shape of the dataframe after outlier removal
print("Shape of dataframe after outlier removal:", df.shape)
# Out:
# Shape of dataframe after outlier removal: (41166, 1035)

# %%
df.describe()
# Out:
#                FLAG      2014/1/1     2014/1/10     2014/1/11     2014/1/12  \
# count  41166.000000  41166.000000  41166.000000  41166.000000  41166.000000
# mean       0.079945      3.499766      3.277922      3.300310      3.533271
# std        0.271211      6.480684      6.464771      6.412743      6.283228
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000274
# 50%        0.000000      0.177344      0.250000      0.357187      0.545278
# 75%        0.000000      4.860000      4.370000      4.440000      4.880000
# max        1.000000    183.390000    415.810000    461.480000    227.340000
#
#           2014/1/13     2014/1/14     2014/1/15     2014/1/16     2014/1/17  \
# count  41166.000000  41166.000000  41166.000000  41166.000000  41166.000000
# mean       3.558026      3.634597      3.743064      3.666295      3.617965
# ...

# %%
## before normalization and standatizaon, hangisini kullancağımıza karar vermemiz için görselleştirip gaussain dağılımın olup olmadığına bakmalıyız


import matplotlib.pyplot as plt
import seaborn as sns

# Define the number of features to visualize (e.g., 10 features)
num_features = 10
features_to_visualize = df.columns[1:num_features+1]  # Exclude the target variable 'FLAG'

# Plot histograms for each feature
plt.figure(figsize=(15, 6*num_features))
for i, feature in enumerate(features_to_visualize, start=1):
    plt.subplot(num_features, 1, i)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
from scipy import stats

# Quantitative assessment
for feature in features_to_visualize:
    print(f"Feature: {feature}")
    print(f"Mean: {df[feature].mean()}")
    print(f"Median: {df[feature].median()}")
    print(f"Standard Deviation: {df[feature].std()}")
    print(f"Skewness: {df[feature].skew()}")
    print(f"Kurtosis: {df[feature].kurtosis()}")
    # Perform Shapiro-Wilk test for normality
    stat, p_value = stats.shapiro(df[feature].dropna())
    print(f"Shapiro-Wilk Test (p-value): {p_value}\n")

# Q-Q plots
plt.figure(figsize=(15, 6*num_features))
for i, feature in enumerate(features_to_visualize, start=1):
    plt.subplot(num_features, 1, i)
    stats.probplot(df[feature], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {feature}')
    plt.xlabel('Theoretical quantiles')
    plt.ylabel('Ordered Values')
plt.tight_layout()
plt.show()
# Out:
# Feature: 2014/1/1
# Mean: 3.499765755875399
# Median: 0.17734375
# Standard Deviation: 6.480683656572774
# Skewness: 3.7033317164168875
# Kurtosis: 31.305152328032793
# Shapiro-Wilk Test (p-value): 0.0
#
# Feature: 2014/1/10
# Mean: 3.2779219751959214
# Median: 0.25
# Standard Deviation: 6.464771251204615
# Skewness: 9.287653991860966
# Kurtosis: 418.30369463412575
# Shapiro-Wilk Test (p-value): 0.0
#
# Feature: 2014/1/11
# Mean: 3.300310084911411
# Median: 0.3571875
# Standard Deviation: 6.41274327138129
# Skewness: 11.597306328196849
# Kurtosis: 646.3337484588061
# Shapiro-Wilk Test (p-value): 0.0
#
# Feature: 2014/1/12
# Mean: 3.533270754506491
# Median: 0.5452777777777778
# Standard Deviation: 6.283228029435787
# Skewness: 4.137449328166149
# Kurtosis: 54.32659971203907
# Shapiro-Wilk Test (p-value): 0.0
#
# Feature: 2014/1/13
# Mean: 3.558026351954547
# Median: 0.69
# Standard Deviation: 6.169395794869576
# Skewness: 3.2971483006333524
# Kurtosis: 17.61184891059504
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Normalization
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df)

# Standardization
scaler = StandardScaler()
standardized_data = scaler.fit_transform(df)

# %%
df.describe()
# Out:
#                FLAG      2014/1/1     2014/1/10     2014/1/11     2014/1/12  \
# count  41166.000000  41166.000000  41166.000000  41166.000000  41166.000000
# mean       0.079945      3.499766      3.277922      3.300310      3.533271
# std        0.271211      6.480684      6.464771      6.412743      6.283228
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000274
# 50%        0.000000      0.177344      0.250000      0.357187      0.545278
# 75%        0.000000      4.860000      4.370000      4.440000      4.880000
# max        1.000000    183.390000    415.810000    461.480000    227.340000
#
#           2014/1/13     2014/1/14     2014/1/15     2014/1/16     2014/1/17  \
# count  41166.000000  41166.000000  41166.000000  41166.000000  41166.000000
# mean       3.558026      3.634597      3.743064      3.666295      3.617965
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of the target variable ('FLAG')
plt.figure(figsize=(8, 6))
sns.countplot(x='FLAG', data=df)
plt.title('Distribution of Target Variable')
plt.xlabel('FLAG')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate percentage of each class
class_counts = df['FLAG'].value_counts(normalize=True) * 100

# Plot the distribution of the target variable ('FLAG') as percentages
plt.figure(figsize=(8, 6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Distribution of Target Variable')
plt.xlabel('FLAG')
plt.ylabel('Percentage')
plt.xticks(ticks=[0, 1], labels=['Class 0', 'Class 1'])  # Assuming binary classification
plt.show()

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Separate features (X) and target variable (y)
X = df.drop(columns=['FLAG'])
y = df['FLAG']

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Concatenate resampled features and target variable into a new DataFrame
df_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='FLAG')], axis=1)

# Visualize the distribution of the target variable after oversampling
plt.figure(figsize=(8, 6))
sns.countplot(x='FLAG', data=df_resampled)
plt.title('Distribution of Target Variable After Oversampling (SMOTE)')
plt.xlabel('FLAG')
plt.ylabel('Count')
plt.show()

# Optionally, you can save the resampled dataset to a new CSV file
# df_resampled.to_csv('resampled_dataset.csv', index=False)

# %%
# up until now
#Missing Values Removal

#Outliers Removal

#Data Type Conversion

#Normalization and Standardization

#Smooth Oversampling (SMOTE)
df.to_csv('processed_data.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Summary Statistics
summary_stats = df.describe()
print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#                FLAG      2014/1/1     2014/1/10     2014/1/11     2014/1/12  \
# count  41166.000000  41166.000000  41166.000000  41166.000000  41166.000000
# mean       0.079945      3.499766      3.277922      3.300310      3.533271
# std        0.271211      6.480684      6.464771      6.412743      6.283228
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000274
# 50%        0.000000      0.177344      0.250000      0.357187      0.545278
# 75%        0.000000      4.860000      4.370000      4.440000      4.880000
# max        1.000000    183.390000    415.810000    461.480000    227.340000
#
#           2014/1/13     2014/1/14     2014/1/15     2014/1/16     2014/1/17  \
# count  41166.000000  41166.000000  41166.000000  41166.000000  41166.000000
# mean       3.558026      3.634597      3.743064      3.666295      3.617965
# ...

# %% [markdown]
# # Data Preprocessing:
#
# ## we have successfully loaded the dataset and handled missing values by interpolating along the columns.
#
# ## Outliers have been detected and removed using the Z-score method.
#
# ## The 'CONS_NO' column has been dropped.
#
# ## Data type conversion has been performed where necessary.
#
# ## Normalization and standardization have been applied to the dataset.
#
# ## Class imbalance has been addressed using the SMOTE technique.
